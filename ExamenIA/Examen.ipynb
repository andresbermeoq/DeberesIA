# %%
import requests

# %%
url = "https://www.google.com/search?q=juan+cristobal+lloret&rlz=1C5CHFA_enEC885EC885&sxsrf=ALeKk028HO4ruhu_Rfs_q7ElZQpGKRSkAg:1610430739374&source=lnms&tbm=nws&sa=X&ved=2ahUKEwjy_J6B2pXuAhWKzlkKHWv6AnYQ_AUoA3oECAUQBQ&biw=1680&bih=857"

# %%
pagina = requests.get(url)

# %%
pagina.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
soap = BeautifulSoup(pagina.text, 'lxml')

# %%
titul = soap.find_all('div', {'class', 'ZINbbc xpd O9g5cc uUPGi'})
titul[1]
# Out:
# <div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&amp;sa=U&amp;ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAF6BAgHEAE&amp;usg=AOvVaw0-iPpAMwV0eQ4H2VHyIW5V"><h3 class="zBAuLc"><div class="BNeawe vvjwJb AP7Wnd">Lloret oficializó el pedido de juicio político al Ministro de Finanzas</div></h3><div class="BNeawe UPmit AP7Wnd">expreso.ec</div></a></div><div class="x54gtf"></div><div class="kCrYT"><a href="/url?q=https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&amp;sa=U&amp;ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAF6BAgHEAI&amp;usg=AOvVaw2U7kJ7pKiMkfoEBiMeiWy0"><div class="lcJF1d SXn0g GXKcHe"><div style="width:120px;height:89px;position:static"><img alt="" class="EYOsld" data-deferred="1" id="dimg_15" src="..." style="width:120px;height:89px"/></div></div></a><div><div class="BNeawe s3v9rd AP7Wnd"><div><div clas
# ...

# %%
c = 0
for item in titul:
    c += 1
    print(c)
    link = item.a.get('href').split('q=')[1:]
    print(link)
    nombre = item.find('div', {'class', 'BNeawe vvjwJb AP7Wnd'})
    titulo = nombre.get_text()
    print(titulo)
    span = item.find('span', {'class': 'r0bn4c rQMQod'})
    tiempo = span.get_text()
    print(tiempo)
    otro = item.find('div', {'class': 'BNeawe s3v9rd AP7Wnd'})
    mensaje = otro.get_text('·').split('·')[1:]
    print(mensaje[2])
# Out:
# 1
# ['https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAB6BAgGEAE&usg=AOvVaw2HMITnsGKTQQr6oks2Pa75']
# Ecuador. Justicia para víctimas de Furukawa
# hace 6 días
# Así mismo, dos Asambleístas de la Comisión de Derechos Colectivos (Juan Cristóbal Lloret y José Chalá Cruz) rindieron sus testimonios...
# 2
# ['https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAF6BAgHEAE&usg=AOvVaw0-iPpAMwV0eQ4H2VHyIW5V']
# Lloret oficializó el pedido de juicio político al Ministro de Finanzas
# hace 7 meses
# El asambleísta Juan Cristóbal Lloret, de la Revolución Ciudadana, oficializó la solicitud de enjuiciamiento político en contra del ministro de...
# 3
# ...

# %%
titulos = soap.find_all('div', {'class':'BNeawe vvjwJb AP7Wnd'})
titulos[1]
# Out:
# <div class="BNeawe vvjwJb AP7Wnd">Lloret oficializó el pedido de juicio político al Ministro de Finanzas</div>

# %%
nombre = titulos[1]

# %%
nombre.get_text()
# Out:
# 'Lloret oficializó el pedido de juicio político al Ministro de Finanzas'

# %%
nombres_titulos = [nombre.get_text() for nombre in titulos]
nombres_titulos
# Out:
# ['Ecuador. Justicia para víctimas de Furukawa',
#  'Lloret oficializó el pedido de juicio político al Ministro de Finanzas',
#  'Correismo: ya hay candidatos a asambleístas en Azuay',
#  'Tributo del 2% a activos de empresas de paraísos fiscales está ...',
#  'La Comisión de Fiscalización recomendará juicio a Romo',
#  'El correísmo anuncia que buscará un juicio político en contra de ...',
#  'Asambleísta Juan Cristóbal Lloret propone norma contra cobros indebidos',
#  'En Azuay se aprobaron 180 candidatos para 5 curules en la Asamblea Nacional',
#  'Preocupación en Azuay y el Austro por el centralismo de la sede de la CELEC en Quito',
#  'Los restos de PAIS cuidan las espaldas al Gobierno en la Asamblea']

# %%
links = soap.find_all('div', {'class':'kCrYT'})

# %%
link = links[1]

# %%
s = link.a.get('href')
s
# Out:
# '/url?q=https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAB6BAgGEAI&usg=AOvVaw3nn_rpxWHnRS3M9t0bDoNE'

# %%
links_completos = [link.a.get('href').split("q=")[1:] for link in links]

# %%
links_completos
# Out:
# [['https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAB6BAgGEAE&usg=AOvVaw2HMITnsGKTQQr6oks2Pa75'],
#  ['https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAB6BAgGEAI&usg=AOvVaw3nn_rpxWHnRS3M9t0bDoNE'],
#  ['https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAF6BAgHEAE&usg=AOvVaw0-iPpAMwV0eQ4H2VHyIW5V'],
#  ['https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAF6BAgHEAI&usg=AOvVaw2U7kJ7pKiMkfoEBiMeiWy0'],
#  ['https://ww2.elmercurio.com.ec/2020/08/20/correismo-ya-hay-candidatos-a-asambleistas-en-azuay/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAJ6BAgJEAE&usg=AOvVaw2BrF2ZGt-s52femv-XXJT3'],
# ...

# %%
dateN = soap.find_all('span', {'class', 'r0bn4c rQMQod'})
dateN
# Out:
# [<span class="r0bn4c rQMQod">hace 6 días</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 7 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 4 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 8 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 2 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 8 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 25 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 2 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 8 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>,
#  <span class="r0bn4c rQMQod">hace 5 meses</span>,
#  <span class="r0bn4c rQMQod"> · </span>]

# %%
date1 = dateN[2]
date1
# Out:
# <span class="r0bn4c rQMQod">hace 7 meses</span>

# %%
date1.get_text()
# Out:
# 'hace 7 meses'

# %%
date_notices = [date1.get_text() for date1 in dateN]
date_notices
# Out:
# ['hace 6 días',
#  ' · ',
#  'hace 7 meses',
#  ' · ',
#  'hace 4 meses',
#  ' · ',
#  'hace 8 meses',
#  ' · ',
#  'hace 2 meses',
#  ' · ',
#  'hace 8 meses',
#  ' · ',
#  'hace 25 meses',
#  ' · ',
#  'hace 2 meses',
#  ' · ',
#  'hace 8 meses',
#  ' · ',
#  'hace 5 meses',
#  ' · ']

# %%
message = soap.find_all('div', {'class', 'BNeawe s3v9rd AP7Wnd'})

# %%
mes = message[1]
mes.get_text().split('· ')[1:]
# Out:
# ['Así mismo, dos Asambleístas de la Comisión de Derechos Colectivos (Juan Cristóbal Lloret y José Chalá Cruz) rindieron sus testimonios...']

# %%
message_notices = [mes.get_text().split('· ')[1:] for mes in message]
message_notices
# Out:
# [['Así mismo, dos Asambleístas de la Comisión de Derechos Colectivos (Juan Cristóbal Lloret y José Chalá Cruz) rindieron sus testimonios...'],
#  ['Así mismo, dos Asambleístas de la Comisión de Derechos Colectivos (Juan Cristóbal Lloret y José Chalá Cruz) rindieron sus testimonios...'],
#  ['El asambleísta Juan Cristóbal Lloret, de la Revolución Ciudadana, oficializó la solicitud de enjuiciamiento político en contra del ministro de...'],
#  ['El asambleísta Juan Cristóbal Lloret, de la Revolución Ciudadana, oficializó la solicitud de enjuiciamiento político en contra del ministro de...'],
#  ['Los cinco aspirantes a llegar al legislativo por Azuay son: Juan Cristóbal Lloret, quien busca la reelección. También están Andrea Verónica...'],
#  ['Los cinco aspirantes a llegar al legislativo por Azuay son: Juan Cristóbal Lloret, quien busca la reelección. También están Andrea Verónica...'],
# ...

# %%
print("Nombres: "+str(len(nombres_titulos))+" Links: "+str(len(links_completos))+" Fechas "
      +str(len(date_notices))+" Mensajes "+str(len(message_notices)))
# Out:
# Nombres: 10 Links: 20 Fechas 20 Mensajes 20

# %%
c = 0
for link in links_completos:
    c+=1
    print(c)
    print(link)
# Out:
# 1
# ['https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAB6BAgGEAE&usg=AOvVaw2HMITnsGKTQQr6oks2Pa75']
# 2
# ['https://kaosenlared.net/ecuador-justicia-para-victimas-de-furukawa/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAB6BAgGEAI&usg=AOvVaw3nn_rpxWHnRS3M9t0bDoNE']
# 3
# ['https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAF6BAgHEAE&usg=AOvVaw0-iPpAMwV0eQ4H2VHyIW5V']
# 4
# ['https://www.expreso.ec/actualidad/lloret-oficializo-pedido-juicio-politico-ministro-finanzas-11660.html&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQ0Y8FMAF6BAgHEAI&usg=AOvVaw2U7kJ7pKiMkfoEBiMeiWy0']
# 5
# ['https://ww2.elmercurio.com.ec/2020/08/20/correismo-ya-hay-candidatos-a-asambleistas-en-azuay/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAJ6BAgJEAE&usg=AOvVaw2BrF2ZGt-s52femv-XXJT3']
# 6
# ...

# %%
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo, RelationshipFrom)
config.DATABASE_URL = 'bolt://neo4j:pandi123@localhost:7687'
class CandidatoNodeU1(StructuredNode):
    nameCandidate = StringProperty(unique_index=True)
    partidoCandidate = StringProperty(unique_index=True)
    
class NoticeCandidatoU1(StructuredNode):
    idNotice = UniqueIdProperty()
    linkNotice = StringProperty(unique_index=False)
    messageNotice = StringProperty(unique_index=False)
    dateNotice = StringProperty(unique_index=False)
    titleNotice = StringProperty(unique_index=False)
    candidatoNotice = RelationshipTo('CandidatoNodeU1', 'Link_de_la_Noticia')

# %%
noticiasPaginas = ['https://www.google.com/search?rlz=1C5CHFA_enEC885EC885&biw=1680&bih=857&tbm=nws&sxsrf=ALeKk02Q4FOVyFXUTw-c4JJQakkdjRgybQ%3A1610455639612&ei=V5r9X8rbJOWb5wKoh5LICw&q=andres+arauz&oq=andres+&gs_l=psy-ab.1.0.0l10.71030.72113.0.76803.7.6.0.1.1.0.127.492.0j4.4.0....0...1c.1.64.psy-ab..2.5.493....0.xB-xJ39RyzY',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk03pX05iGwTpkbDq8YVkaFnvntc43w:1610455716972&ei=pJr9X-nlOoyu5wLQ6beQCw&start=10&sa=N&ved=0ahUKEwjpx76Ht5buAhUM11kKHdD0DbIQ8tMDCIYB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk00uIRgTY3M33D5IaA_rNXfkLk4hQQ:1610455761556&ei=0Zr9X_bFIcyo5gKm-bXgAw&start=20&sa=N&ved=0ahUKEwi28t-ct5buAhVMlFkKHaZ8DTw4HhDy0wMIhwE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk03gfjn2B0Yizks860rpBSRApYMHuA:1610455772307&ei=3Jr9X8-aEqLl5gKf5rLwBw&start=30&sa=N&ved=0ahUKEwjP-O-ht5buAhWislkKHR-zDH44KBDy0wMIiAE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02aqJRWD-P2-i-bayV2r6lQrxD46w:1610455774720&ei=3pr9X8TCK6LZ5gLGtKnICg&start=40&sa=N&ved=0ahUKEwjEqYOjt5buAhWirFkKHUZaCqk4HhDy0wMIigE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk01ILvO0aBZJwUEirBSYilx8KZTCwg:1610455808552&ei=AJv9X7OpIY605gK37om4Dw&start=50&sa=N&ved=0ahUKEwizqZSzt5buAhUOmlkKHTd3Avc4KBDy0wMIiwE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk030NyPt6L3wgTHtqOwGcr_IwCmHpg:1610455818953&ei=Cpv9X_7fOZCD5wLj26HgAQ&start=60&sa=N&ved=0ahUKEwj-jI-4t5buAhWQwVkKHeNtCBw4MhDy0wMIjwE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk03gcaCrggeTM8jbGPz3OB6cHMC6-A:1610455827998&ei=E5v9X-TCPIbb5gKxxLyQBA&start=70&sa=N&ved=0ahUKEwikmLe8t5buAhWGrVkKHTEiD0I4PBDy0wMIkQE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk03ffp3Mp5sV7YVU6lgKTgevKG9gEQ:1610455860956&ei=NJv9X5DxOa7n5gLMk4GQCw&start=80&sa=N&ved=0ahUKEwiQ25LMt5buAhWus1kKHcxJALI4RhDy0wMIlAE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk00j2j_BKULV-jJvFVCZvkkVq6mgLw:1610455871506&ei=P5v9X8e9HqqG5wKMybko&start=90&sa=N&ved=0ahUKEwiH2ZbRt5buAhUqw1kKHYxkDgU4UBDy0wMIlgE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02vvGIeYBw8zkr0qjZV0LwB5t-kPQ:1610455881524&ei=SZv9X464H42E5wKP55XADA&start=100&sa=N&ved=0ahUKEwjOgPrVt5buAhUNwlkKHY9zBcg4WhDy0wMImAE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02fgg0njLue1AWXc_rn-opyEKQHgQ:1610455894832&ei=Vpv9X-OnMquw5wK-qYTQAw&start=110&sa=N&ved=0ahUKEwjjqqbct5buAhUr2FkKHb4UATo4ZBDy0wMImgE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk00rQk1vAtyGt0Zn9F3m9B2ducZazw:1610455903935&ei=X5v9X8PFOIOu5wLqgbzgCQ&start=120&sa=N&ved=0ahUKEwiD8dHgt5buAhUD11kKHeoAD5w4bhDy0wMImgE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk00wN3tpzBDyQ_r70dP0R8epRDnIbA:1610455913368&ei=aZv9X7P8FbGw5wLOqZW4Dg&start=130&sa=N&ved=0ahUKEwjz1JHlt5buAhUx2FkKHc5UBec4eBDy0wMImgE&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk00QaQFjsHwACmD9WgENNG6_kq8-GA:1610455921173&ei=cZv9X57sCary5gKbhrSYCQ&start=140&sa=N&ved=0ahUKEwje6O3ot5buAhUquVkKHRsDDZM4ggEQ8tMDCJoB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02Jpuva_J01_XGJqvNEX1KP9RcTeA:1610455929948&ei=eZv9X7WvOeOn5wLE1rCoDw&start=150&sa=N&ved=0ahUKEwj1z4Xtt5buAhXj01kKHUQrDPU4jAEQ8tMDCJoB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk002LGL6zLQnizqkR3i8TpQjhwkIhQ:1610455963360&ei=m5v9X8fIFYzz5gLSpZzABw&start=160&sa=N&ved=0ahUKEwiHgv38t5buAhWMuVkKHdISB3g4lgEQ8tMDCJoB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02M_CNTqekUBLD4W30BPtJ-agbI3A:1610455973514&ei=pZv9X7LlHoip5wLM_5OYBg&start=170&sa=N&ved=0ahUKEwjyy-iBuJbuAhWI1FkKHcz_BGM4oAEQ8tMDCJkB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk0054-o0-76ayIXyBXtlQXu-oEI2ag:1610455984084&ei=sJv9X-7LBIq35gKFxa_ACw&start=180&sa=N&ved=0ahUKEwju4-2GuJbuAhWKm1kKHYXiC7g4qgEQ8tMDCJoB&biw=1680&bih=857&dpr=2',
                   'https://www.google.com/search?q=andres+arauz&rlz=1C5CHFA_enEC885EC885&tbm=nws&sxsrf=ALeKk02jSqFY4zUx8ruDeQr3ftSTZmFnsQ:1610455993902&ei=uZv9X5a6NoKs5wKrmLvoDQ&start=190&sa=N&ved=0ahUKEwjW-sSLuJbuAhUC1lkKHSvMDt04tAEQ8tMDCJoB&biw=1680&bih=857&dpr=2',]

contador = 0
candidato_unes = CandidatoNodeU1(nameCandidate="Andres Arauz", partidoCandidate="UNES").save()
for url in noticiasPaginas:
    url_noticias = url
    ingreso = requests.get(url_noticias)
    contenido_pagina = BeautifulSoup(ingreso.text, 'lxml')
    
    
    noticias = soap.find_all('div', {'class', 'ZINbbc xpd O9g5cc uUPGi'})
    for noticia in noticias:
        print('=================================================')
        contador +=1
        print(contador)
        link = item.a.get('href').split('q=')[1:]
        print(link)
        nombre = item.find('div', {'class', 'BNeawe vvjwJb AP7Wnd'})
        titulo_noticia = nombre.get_text()
        print(titulo_noticia)
        span = item.find('span', {'class': 'r0bn4c rQMQod'})
        date_noticia = span.get_text()
        print(date_noticia)
        mensaje = item.find('div', {'class': 'BNeawe s3v9rd AP7Wnd'})
        mensaje_noticia = otro.get_text('·').split('·')[1:]
        print(mensaje_noticia[2])
        
        noticia = NoticeCandidatoU1(idNotice=contador, linkNotice=link, messageNotice=mensaje_noticia[2], dateNotice=date_noticia, titleNotice=titulo_noticia).save()
        noticia.candidatoNotice.connect(candidato_unes)
        print('Datos Guardados')
        print('================================================')
# Out:
# ...
# 1
# ['https://www.primicias.ec/noticias/politica/restos-oficialismo-espaldas-gobierno-asamblea/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAl6BAgDEAE&usg=AOvVaw1mNd7VIsHLK1tEshUc_L3M']
# Los restos de PAIS cuidan las espaldas al Gobierno en la Asamblea
# hace 5 meses
# Por esa razón el legislador Juan Cristóbal Lloret (RC) incluso ha propuesto en tres ocasiones cambios del orden del día para que la Asamblea...
# Datos Guardados
# ...
# 2
# ['https://www.primicias.ec/noticias/politica/restos-oficialismo-espaldas-gobierno-asamblea/&sa=U&ved=2ahUKEwiS2PHIipbuAhUm2FkKHQheAnIQxfQBMAl6BAgDEAE&usg=AOvVaw1mNd7VIsHLK1tEshUc_L3M']
# Los restos de PAIS cuidan las espaldas al Gobierno en la Asamblea
# hace 5 meses
# Por esa razón el legislador Juan Cristóbal Lloret (RC) incluso ha propuesto en tres ocasiones cambios del orden del día para que la Asamblea...
# Datos Guardados
# ...
# 3
# ...
